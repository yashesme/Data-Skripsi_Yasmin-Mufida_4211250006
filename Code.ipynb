# %% [markdown]
# ### **IMPORT DATA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_excel('/content/Dataset BAPOMI.xlsx')
df
# Out:
#       NO        CLUB                    NAMA  TAHUN L/P     TB     BB  \
# 0      1  ZTC BINJAI   ALIKHA CORDELIA PUTRI   2015   P  126.0   28.0
# 1      2  ZTC BINJAI   OCTAVANY ADELIA PUTRI   2016   P  123.0   36.0
# 2      3  ZTC BINJAI    KENZO ALVARO GINTING   2016   L  130.0   30.0
# 3      4  ZTC BINJAI           AISYAH AQILLA   2013   P  149.0   49.0
# 4      5  ZTC BINJAI          RIFQI SYAHBANA   2014   L  140.0   30.0
# ..   ...         ...                     ...    ...  ..    ...    ...
# 551  552    MIKRONOM  Wanti Octaviany Haloho   2011   P  155.0   42.0
# 552  553    MIKRONOM         Aulia Hutabarat   2011   P  150.0   53.0
# 553  554    MIKRONOM            Alwyna Purba   2011   P  159.0   58.0
# 554  555    MIKRONOM        Kevin Rusvinaldi   2004   L  170.0  115.0
# 555  556    MIKRONOM   Kaleb Yoan vino purba   2004   L  185.0  105.0
#
#     KATEGORI FESTIVAL
# 0          PRAKADET B
# 1          PRAKADET B
# 2          PRAKADET B
# 3          PRAKADET C
# 4          PRAKADET C
# ..                ...
# 551             KADET
# 552             KADET
# 553             KADET
# 554            SENIOR
# 555            SENIOR
#
# [556 rows x 8 columns]

# %% [markdown]
# ### **DATA CLEANING**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NO                 556 non-null    int64
#  1   CLUB               556 non-null    object
#  2   NAMA               556 non-null    object
#  3   TAHUN              556 non-null    int64
#  4   L/P                556 non-null    object
#  5   TB                 544 non-null    float64
#  6   BB                 544 non-null    float64
#  7   KATEGORI FESTIVAL  556 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 34.9+ KB

# %%
df = df.drop(columns=['NO'])

# %%
df.isnull().sum()
# Out:
# CLUB                  0
# NAMA                  0
# TAHUN                 0
# L/P                   0
# TB                   12
# BB                   12
# KATEGORI FESTIVAL     0
# dtype: int64

# %%
df = df.dropna(subset=['TB', 'BB'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 544 entries, 0 to 555
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CLUB               544 non-null    object
#  1   NAMA               544 non-null    object
#  2   TAHUN              544 non-null    int64
#  3   L/P                544 non-null    object
#  4   TB                 544 non-null    float64
#  5   BB                 544 non-null    float64
#  6   KATEGORI FESTIVAL  544 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 34.0+ KB

# %%
print(df['KATEGORI FESTIVAL'].unique())
# Out:
# ['PRAKADET B' 'PRAKADET C' 'KADET' 'JUNIOR' 'PRAKADET A' 'SENIOR']

# %%
scaler = StandardScaler()
X = df[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### **MEMISAHKAN SETIAP KATEGORI FESTIVAL BERDASARKAN JENIS KELAMIN**

# %%
jumlah_peserta_per_kategori = df.groupby('KATEGORI FESTIVAL')['NAMA'].count().reset_index()
jumlah_peserta_per_kategori = jumlah_peserta_per_kategori.rename(columns={'NAMA': 'JUMLAH PESERTA'})
jumlah_peserta_per_kategori
# Out:
#   KATEGORI FESTIVAL  JUMLAH PESERTA
# 0            JUNIOR             114
# 1             KADET             154
# 2        PRAKADET A              38
# 3        PRAKADET B              62
# 4        PRAKADET C             103
# 5            SENIOR              73

# %%
festival_per_jk = df.groupby(['KATEGORI FESTIVAL', 'L/P']).size().reset_index(name='JUMLAH PESERTA')
festival_per_jk
# Out:
#    KATEGORI FESTIVAL L/P  JUMLAH PESERTA
# 0             JUNIOR   L              75
# 1             JUNIOR   P              39
# 2              KADET   L              88
# 3              KADET   P              66
# 4         PRAKADET A   L              33
# 5         PRAKADET A   P               5
# 6         PRAKADET B   L              37
# 7         PRAKADET B   P              25
# 8         PRAKADET C   L              76
# 9         PRAKADET C   P              27
# 10            SENIOR   L              44
# 11            SENIOR   P              29

# %%
import matplotlib.pyplot as plt
import numpy as np

# Daftar kategori unik
kategori_unik = df['KATEGORI FESTIVAL'].unique()

rows = int(np.ceil(len(kategori_unik) / 2))
cols = 2

fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten()

for idx, kategori in enumerate(kategori_unik):
    df_kat = df[df['KATEGORI FESTIVAL'] == kategori]

    df_L = df_kat[df_kat['L/P'] == 'L']
    df_P = df_kat[df_kat['L/P'] == 'P']

    # Plot batang untuk laki-laki
    axes[idx].bar(df_L['TB'], df_L['BB'], color='navy', alpha=0.7, label='Laki-laki')
    # Plot batang untuk perempuan
    axes[idx].bar(df_P['TB'], df_P['BB'], color='palevioletred', alpha=0.7, label='Perempuan')

    axes[idx].set_title(f"{kategori}")
    axes[idx].set_xlabel('Tinggi Badan (cm)')
    axes[idx].set_ylabel('Berat Badan (kg)')
    axes[idx].legend()

for ax in axes[len(kategori_unik):]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **PRAKADET A**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
prakadet_a_lk = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET A') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'PRAKADET A' Laki-laki: {len(prakadet_a_lk)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET A' Laki-laki: 33

# %%
prakadet_a_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet A Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_a_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Prakadet A Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  66.000000            NaN
# 1   2  32.856562      33.143438
# 2   3  17.358786      15.497776
# 3   4  12.423200       4.935586
# 4   5   9.533118       2.890081
# 5   6   7.451034       2.082084
# 6   7   5.460116       1.990918
# 7   8   4.432346       1.027770
# 8   9   3.834450       0.597897
# 9  10   3.050180       0.784269

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_a_lk_clustered = prakadet_a_lk.copy()
prakadet_a_lk_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_a_lk_clustered['cluster'].unique()):
    cluster_data = prakadet_a_lk_clustered[prakadet_a_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_a_lk_clustered[prakadet_a_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                            CLUB                               NAMA  TAHUN L/P  \
# 75                       HASAKU           GIBRAN ATHALLAH NASUTION   2017   L
# 91                         KTTC            RAMADHAN ASHKII ALTHANI   2017   L
# 161             KHENZUA FIGHTER                   MHD ARKHA AIDIEL   2017   L
# 165          RAI TAEKWONDO TEAM          Jehezkiel Billy Panjaitan   2018   L
# 166          RAI TAEKWONDO TEAM               Alvaro Givariel Hulu   2017   L
# 167          RAI TAEKWONDO TEAM               Fairuz Azka Nugraha    2017   L
# 211       TIGER SUMATERA BINJAI             HARRY AL ZIKRI TARIGAN   2017   L
# 212       TIGER SUMATERA BINJAI         FABIAN ATTARSYAH KRISNANDA   2017   L
# 213       TIGER SUMATERA BINJAI          MARTOGI PEREIRA SIMARMATA   2019   L
# 214       TIGER SUMATERA BINJAI       KENWARD MESAKH GRAT SEBAYANG   2017   L
# 215       TIGER SUMATERA BINJAI                     ABQORI ARSENIO   2017   L
# 216       TIGER SUMATERA BINJAI                 REYNAND ALZARO GEA   2017   L
# 262         Badar Nurul Iman TC                   IBNU RAZKA AUFAA   2017   L
# 269         Champion Fighter TC  Alvaro Gavriel Sohahuaon Sianturi   2017   L
# 285          SIBAYAK LIONS CLUB                  EVAN GIAN GINTING   2017   L
# 286          SIBAYAK LIONS CLUB                 AARON JOSUA MARBUN   2013   L
# 324  Macan Taekwondo Club Medan                   Haikal Abhisatya   2017   L
# 457                         GSM                  AHDA KAIZEN HAKIM   2017   L
# 533                    MIKRONOM       Garry Nathan Alfares Siahaan   2018   L
# 536                    MIKRONOM                           Pangeran   2017   L
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 75   115.0  28.0        PRAKADET A        0
# 91   120.0  20.0        PRAKADET A        0
# 161  125.0  23.0        PRAKADET A        0
# 165  117.0  18.0        PRAKADET A        0
# 166  116.0  20.0        PRAKADET A        0
# 167  123.0  21.0        PRAKADET A        0
# 211  121.0  18.0        PRAKADET A        0
# 212  119.0  18.0        PRAKADET A        0
# 213  119.0  28.0        PRAKADET A        0
# 214  120.0  22.0        PRAKADET A        0
# 215  115.0  24.0        PRAKADET A        0
# 216  120.0  20.0        PRAKADET A        0
# 262  125.0  22.0        PRAKADET A        0
# 269  115.0  30.0        PRAKADET A        0
# 285  121.0  24.0        PRAKADET A        0
# 286  125.0  26.0        PRAKADET A        0
# 324  124.0  19.5        PRAKADET A        0
# 457  125.0  21.0        PRAKADET A        0
# 533  127.0  26.0        PRAKADET A        0
# 536  123.0  25.8        PRAKADET A        0
#
# Cluster 2:
#                     CLUB                      NAMA  TAHUN L/P     TB    BB  \
# 57     FATHUR-RAHMAN TKD           PARASIAN AKHTAR   2018   L  105.0  21.5
# 90                  KTTC     MUHAMMAD ABUZAR SAKHI   2017   L  100.0  18.0
# 160      KHENZUA FIGHTER         MUHAMMAD ALGAZALI   2019   L  105.0  16.0
# 267  Champion Fighter TC  Sandri Abdillah Sandjaya   2018   L  110.0  20.0
# 268  Champion Fighter TC  Geonathan Azel Situmeang   2018   L   90.0  16.0
# 526             MIKRONOM  ERIK HEZESKIEL SIHOMBING   2017   L  105.0  22.0
#
#     KATEGORI FESTIVAL  cluster
# 57         PRAKADET A        1
# 90         PRAKADET A        1
# 160        PRAKADET A        1
# 267        PRAKADET A        1
# 268        PRAKADET A        1
# 526        PRAKADET A        1
#
# Cluster 3:
#                       CLUB                        NAMA  TAHUN L/P     TB  \
# 19   HTC PUTRA JAYA STABAT      FRANCE HISKIA SIMAMORA   2018   L  138.0
# 287     SIBAYAK LIONS CLUB              ADRIEL ERLANDO   2013   L  130.0
# 288     SIBAYAK LIONS CLUB  JOSIA BHARLIND SIBAGARIANG   2013   L  120.0
# 289     SIBAYAK LIONS CLUB              AGUERO TARIGAN   2013   L  135.0
# 290     SIBAYAK LIONS CLUB     CHRISTIAN PUTRA GINTING   2014   L  140.0
# 368       Simpang Selayang                      Arhan    2017   L  129.0
# 408         UNPRI TKD CLUB                      Alfath   2017   L  132.0
#
#        BB KATEGORI FESTIVAL  cluster
# 19   30.0        PRAKADET A        2
# 287  30.0        PRAKADET A        2
# 288  35.0        PRAKADET A        2
# 289  35.0        PRAKADET A        2
# 290  41.0        PRAKADET A        2
# 368  30.0        PRAKADET A        2
# 408  42.0        PRAKADET A        2

# %% [markdown]
# ### 2. PEREMPUAN

# %%
prakadet_a_pr = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET A') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'PRAKADET A' Perempuan: {len(prakadet_a_pr)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET A' Perempuan: 5

# %%
prakadet_a_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet A Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_a_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 6):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 6), inertia, marker='o')
plt.xticks(range(1, 6))
plt.title('Elbow Method - Prakadet A Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#    k        SSE  Penurunan_SSE
# 0  1  10.000000            NaN
# 1  2   2.665297       7.334703
# 2  3   1.193624       1.471673
# 3  4   0.268841       0.924783
# 4  5   0.000000       0.268841

# %%
k_manual = 2
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_a_pr_clustered = prakadet_a_pr.copy()
prakadet_a_pr_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_a_pr_clustered['cluster'].unique()):
    cluster_data = prakadet_a_pr_clustered[prakadet_a_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(6, 4))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_a_pr_clustered[prakadet_a_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                    CLUB                  NAMA  TAHUN L/P     TB    BB  \
# 291  SIBAYAK LIONS CLUB  ALEXA TERESIA HAREFA   2013   P  130.0  32.0
# 342      Golden Warrior            Cut Meymey   2017   P  122.0  25.0
#
#     KATEGORI FESTIVAL  cluster
# 291        PRAKADET A        0
# 342        PRAKADET A        0
#
# Cluster 2:
#                            CLUB                       NAMA  TAHUN L/P     TB  \
# 112    Ar-rahman Taekwondo Club  Shofiyah Ayudisa Alfarisi   2018   P  112.0
# 325  Macan Taekwondo Club Medan      Lathifah Azmah Kirana   2017   P  118.0
# 422                    JOHOR TC           Luthfiana Marsya   2017   P  105.0
#
#        BB KATEGORI FESTIVAL  cluster
# 112  20.0        PRAKADET A        1
# 325  19.0        PRAKADET A        1
# 422  20.0        PRAKADET A        1

# %% [markdown]
# ### **PRAKADET B**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
prakadet_b_lk = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET B') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'PRAKADET B' Laki-laki: {len(prakadet_b_lk)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET B' Laki-laki: 37

# %%
prakadet_b_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet B Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_b_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Prakadet B Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  74.000000            NaN
# 1   2  36.346832      37.653168
# 2   3  16.845419      19.501414
# 3   4  10.226689       6.618730
# 4   5   7.225625       3.001063
# 5   6   5.353724       1.871901
# 6   7   4.483154       0.870570
# 7   8   3.805564       0.677590
# 8   9   3.424279       0.381285
# 9  10   2.760064       0.664215

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_b_lk_clustered = prakadet_b_lk.copy()
prakadet_b_lk_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_b_lk_clustered['cluster'].unique()):
    cluster_data = prakadet_b_lk_clustered[prakadet_b_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_b_lk_clustered[prakadet_b_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                    CLUB                       NAMA  TAHUN L/P     TB    BB  \
# 2            ZTC BINJAI       KENZO ALVARO GINTING   2016   L  130.0  30.0
# 38            MAVERICKS             GABRIEL MANALU   2015   L  130.0  29.0
# 77               HASAKU      CLAUDIO TIMOTHY MANIK   2015   L  135.0  36.0
# 123        TI BATU BARA               ALMALIK AQWA   2016   L  130.0  33.0
# 124        TI BATU BARA             DAFFA PRASETYO   2015   L  130.0  30.0
# 169  RAI TAEKWONDO TEAM         Hauzan Irhab Nabil   2015   L  140.0  42.0
# 361                 PTA       FATHIR ABIGAIL MASKA   2015   L  135.0  34.0
# 362                 PTA     LOUIS TRISTAN MARANATA   2015   L  135.0  33.0
# 369    Simpang Selayang             Muhammed Keano   2015   L  135.0  35.0
# 377         PAB SAENTIS           AL-KAHFI GIFHARI   2015   L  128.0  30.0
# 410      UNPRI TKD CLUB  Aldrik El Kareem Marpaung   2016   L  135.0  31.0
# 411      UNPRI TKD CLUB       Zeeshan Ahmad Waruwu   2016   L  135.0  28.0
# 532            MIKRONOM           Elward Tandiyono   2016   L  132.0  43.0
#
#     KATEGORI FESTIVAL  cluster
# 2          PRAKADET B        0
# 38         PRAKADET B        0
# 77         PRAKADET B        0
# 123        PRAKADET B        0
# 124        PRAKADET B        0
# 169        PRAKADET B        0
# 361        PRAKADET B        0
# 362        PRAKADET B        0
# 369        PRAKADET B        0
# 377        PRAKADET B        0
# 410        PRAKADET B        0
# 411        PRAKADET B        0
# 532        PRAKADET B        0
#
# Cluster 2:
#                            CLUB                             NAMA  TAHUN L/P  \
# 36                    MAVERICKS               FILEMON SITUMORANG   2016   L
# 37                    MAVERICKS           YOSIA PAHOT SITANGGANG   2016   L
# 72                    HIRMAT TC       Muhammad Kabiir Al - Fatah   2015   L
# 133               RAJAWALI CLUB                     M Tri Haikal   2016   L
# 134               RAJAWALI CLUB        Reinhard Natanael Saragih   2015   L
# 145                   FERACO TC              DENIS AULYA PRATAMA   2015   L
# 168          RAI TAEKWONDO TEAM                   Rifky Budiman    2015   L
# 199                 ALAM LEUSER                        AL KHAFI    2015   L
# 218       TIGER SUMATERA BINJAI               AZKA AZZAMI FATHAN   2016   L
# 219       TIGER SUMATERA BINJAI                   M ADITYA ARIZA   2016   L
# 228       TIGER SUMATERA BINJAI                 RAVATIH AL HAKIM   2015   L
# 326  Macan Taekwondo Club Medan           Abiandra Argani Suman    2015   L
# 327  Macan Taekwondo Club Medan                  Jazzy El Zaheer   2016   L
# 370            Simpang Selayang      Dzaky Yodah Hasani Hasibuan   2016   L
# 371            Simpang Selayang   Assraf  Ellnsihasari Hasibuan    2015   L
# 376                 PAB SAENTIS                       AZKA AZFAR   2015   L
# 426                TBBC BELAWAN                  MUHAMMAD HABIBI   2016   L
# 428                TBBC BELAWAN          ALEXANDER SONANG SIRAIT   2015   L
# 535                    MIKRONOM                     Kris Tananda   2016   L
# 543                    MIKRONOM  Partogi Naldo Haruko Mangunsong   2015   L
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 36   125.0  22.0        PRAKADET B        1
# 37   120.0  22.0        PRAKADET B        1
# 72   125.0  25.0        PRAKADET B        1
# 133  129.0  24.0        PRAKADET B        1
# 134  120.0  25.0        PRAKADET B        1
# 145  125.0  25.0        PRAKADET B        1
# 168  125.0  21.0        PRAKADET B        1
# 199  133.0  24.0        PRAKADET B        1
# 218  130.0  28.0        PRAKADET B        1
# 219  126.0  24.0        PRAKADET B        1
# 228  128.0  26.0        PRAKADET B        1
# 326  132.0  25.0        PRAKADET B        1
# 327  120.0  17.0        PRAKADET B        1
# 370  130.0  26.0        PRAKADET B        1
# 371  130.0  27.0        PRAKADET B        1
# 376  120.0  24.0        PRAKADET B        1
# 426  129.0  24.0        PRAKADET B        1
# 428  128.0  26.0        PRAKADET B        1
# 535  120.0  22.0        PRAKADET B        1
# 543  127.0  21.0        PRAKADET B        1
#
# Cluster 3:
#                       CLUB                                 NAMA  TAHUN L/P  \
# 217  TIGER SUMATERA BINJAI              KASYAFA ABINAYA GINTING   2016   L
# 375            PAB SAENTIS                     ALKHALIFI KHAIRY   2016   L
# 423               JOHOR TC                      Mhd Taqiy Rajwa   2018   L
# 525               MIKRONOM  JORDANIO MARANDREAS ANGGIAT SIAHAAN   2015   L
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 217  102.0  18.0        PRAKADET B        2
# 375  110.0  18.0        PRAKADET B        2
# 423  100.0  18.0        PRAKADET B        2
# 525  101.0  22.0        PRAKADET B        2

# %% [markdown]
# ### 2. PEREMPUAN

# %%
prakadet_b_pr = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET B') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'PRAKADET B' Perempuan: {len(prakadet_b_pr)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET B' Perempuan: 25

# %%
prakadet_b_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet B Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_b_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Prakadet B Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  50.000000            NaN
# 1   2  21.841617      28.158383
# 2   3  12.372403       9.469214
# 3   4   8.693867       3.678536
# 4   5   6.433817       2.260051
# 5   6   4.776201       1.657616
# 6   7   3.689523       1.086678
# 7   8   2.872029       0.817494
# 8   9   2.410951       0.461079
# 9  10   1.765308       0.645643

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_b_pr_clustered = prakadet_b_pr.copy()
prakadet_b_pr_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_b_pr_clustered['cluster'].unique()):
    cluster_data = prakadet_b_pr_clustered[prakadet_b_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_b_pr_clustered[prakadet_b_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                       CLUB                               NAMA  TAHUN L/P  \
# 0               ZTC BINJAI              ALIKHA CORDELIA PUTRI   2015   P
# 1               ZTC BINJAI              OCTAVANY ADELIA PUTRI   2016   P
# 20   HTC PUTRA JAYA STABAT          Farriisha Ivana Togatorop   2016   P
# 21   HTC PUTRA JAYA STABAT        Annisa Syaudiya Azalia Eisa   2016   P
# 106         Durin tonggal            Fika Flora Br Gurusinga    2014   P
# 135          RAJAWALI CLUB           Salsa Bila Sekar Lathifa   2015   P
# 221  TIGER SUMATERA BINJAI   STANISVANIA GALVANI BR SIMARMATA   2016   P
# 222  TIGER SUMATERA BINJAI              KIANDRA ANAIA GINTING   2015   P
# 227  TIGER SUMATERA BINJAI                ARSHYFA SATYA AYURI   2016   P
# 343         Golden Warrior  Aulia Salsabila Br Perangin-angin   2015   P
# 379            PAB SAENTIS                MAHIRA HASNA KAMILA   2015   P
# 458                    GSM             KEYSHA KAIRINA RITONGA   2016   P
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 0    126.0  28.0        PRAKADET B        0
# 1    123.0  36.0        PRAKADET B        0
# 20   135.0  26.0        PRAKADET B        0
# 21   130.0  22.0        PRAKADET B        0
# 106  130.0  28.0        PRAKADET B        0
# 135  131.0  22.0        PRAKADET B        0
# 221  125.0  22.0        PRAKADET B        0
# 222  128.0  22.0        PRAKADET B        0
# 227  131.0  28.0        PRAKADET B        0
# 343  126.0  28.0        PRAKADET B        0
# 379  132.0  24.0        PRAKADET B        0
# 458  125.0  25.0        PRAKADET B        0
#
# Cluster 2:
#                          CLUB                     NAMA  TAHUN L/P     TB  \
# 35                  MAVERICKS      PUTERI BADAR RAHAYU   2015   P  133.0
# 76                     HASAKU            BILQIS UFAIRA   2015   P  130.0
# 92                       KTTC  FATIN HUMAIRA ARMEISYAH   2015   P  138.0
# 113  Ar-rahman Taekwondo Club  Kirana Fakhira Alfarisi   2016   P  135.0
# 225     TIGER SUMATERA BINJAI      NURITA AISYAH PUTRI   2015   P  135.0
# 409            UNPRI TKD CLUB     Ashira Islami Yadika   2015   P  145.0
#
#         BB KATEGORI FESTIVAL  cluster
# 35   45.00        PRAKADET B        1
# 76   39.00        PRAKADET B        1
# 92   33.09        PRAKADET B        1
# 113  45.00        PRAKADET B        1
# 225  36.00        PRAKADET B        1
# 409  35.00        PRAKADET B        1
#
# Cluster 3:
#                       CLUB                                 NAMA  TAHUN L/P  \
# 93                    KTTC                      FATIMAH AZZAHRA   2015   P
# 220  TIGER SUMATERA BINJAI         ADIBA SYAQILA BR TELAUMBANUA   2015   P
# 223  TIGER SUMATERA BINJAI                  RALINE HAURA FALISA   2015   P
# 224  TIGER SUMATERA BINJAI                     AGUS TRIANY ZIRE   2016   P
# 226  TIGER SUMATERA BINJAI  JANE FEBRIANI HUMAIRAH BR HUTABARAT   2015   P
# 378            PAB SAENTIS                    RASYIQAH AZ-ZAHRA   2015   P
# 427           TBBC BELAWAN                JASMINE AZZAHRA PUTRI   2016   P
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 93   123.0  23.5        PRAKADET B        2
# 220  120.0  22.0        PRAKADET B        2
# 223  117.0  24.0        PRAKADET B        2
# 224  117.0  22.0        PRAKADET B        2
# 226  118.0  18.0        PRAKADET B        2
# 378  122.0  20.0        PRAKADET B        2
# 427  118.0  18.0        PRAKADET B        2

# %% [markdown]
# ### **PRAKADET C**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
prakadet_c_lk = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET C') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'PRAKADET C' Laki-laki: {len(prakadet_c_lk)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET C' Laki-laki: 76

# %%
prakadet_c_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet C Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_c_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Prakadet C Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k         SSE  Penurunan_SSE
# 0   1  152.000000            NaN
# 1   2   70.753883      81.246117
# 2   3   48.029029      22.724854
# 3   4   39.296384       8.732645
# 4   5   30.759654       8.536730
# 5   6   23.912070       6.847584
# 6   7   19.642195       4.269874
# 7   8   16.158956       3.483239
# 8   9   13.253845       2.905111
# 9  10   10.425953       2.827892

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_c_lk_clustered = prakadet_c_lk.copy()
prakadet_c_lk_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_c_lk_clustered['cluster'].unique()):
    cluster_data = prakadet_c_lk_clustered[prakadet_c_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_c_lk_clustered[prakadet_c_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                            CLUB                            NAMA  TAHUN L/P  \
# 6                    ZTC BINJAI        AZKA ABQARY AZMI SIAHAAN   2013   L
# 7                    ZTC BINJAI          ALARIC TRISTAN TARIGAN   2013   L
# 8                    ZTC BINJAI        LIONEL HABIBINTA MELIALA   2013   L
# 47                    MAVERICKS                     ROBI SARAGI   2014   L
# 79                       HASAKU                   KEANU ALFATAN   2013   L
# 80                       HASAKU            FAIZ HABIBI BUDIMAN    2013   L
# 82                       HASAKU               MHD AZZAM SYAZANI   2013   L
# 136               RAJAWALI CLUB             Arda Yulianda Putra   2013   L
# 147                  MTC SERGAI        GIANO AZHRIEL HUTAGALUNG   2013   L
# 170          RAI TAEKWONDO TEAM              Andrian  Surbakti    2014   L
# 233       TIGER SUMATERA BINJAI           MUHAMMAD FAREL ADETYA   2013   L
# 236       TIGER SUMATERA BINJAI        FADHILLAH AKBAR SURBAKTI   2013   L
# 265  WOLF REBORN TAEKWONDO TEAM            EDI RYCARDO SIPAYUNG   2013   L
# 271                     R.A ONE              FAHRI HASSAN UKAIL   2013   L
# 328  Macan Taekwondo Club Medan          Alkhalifi Ahmad Hakiki   2014   L
# 364                         PTA     MUHAMMAD AKHSAN BAIHAQI RAO   2013   L
# 372            Simpang Selayang        Rangga Chalfaro Tarigan    2014   L
# 384                 PAB SAENTIS                   OSHKY PRATAMA   2013   L
# 412              UNPRI TKD CLUB                 Fatih Abdullah    2013   L
# 460                         GSM                  NAUFAL RITONGA   2014   L
# 537               MIKRONOM                    Kevin Tananda   2013   L  135.0
#
#        BB KATEGORI FESTIVAL  cluster
# 4    30.0        PRAKADET C        2
# 5    33.0        PRAKADET C        2
# 41   30.0        PRAKADET C        2
# 45   30.0        PRAKADET C        2
# 48   28.0        PRAKADET C        2
# 49   36.0        PRAKADET C        2
# 50   28.0        PRAKADET C        2
# 60   31.9        PRAKADET C        2
# 78   28.0        PRAKADET C        2
# 95   35.0        PRAKADET C        2
# 107  45.0        PRAKADET C        2
# 137  38.0        PRAKADET C        2
# 146  30.0        PRAKADET C        2
# 171  30.0        PRAKADET C        2
# 189  31.0        PRAKADET C        2
# 201  30.0        PRAKADET C        2
# 202  30.0        PRAKADET C        2
# 231  28.0        PRAKADET C        2
# 232  36.0        PRAKADET C        2
# 234  30.0        PRAKADET C        2
# 336  31.0        PRAKADET C        2
# 381  24.0        PRAKADET C        2
# 382  26.0        PRAKADET C        2
# 383  26.0        PRAKADET C        2
# 390  28.0        PRAKADET C        2
# 391  30.0        PRAKADET C        2
# 414  30.0        PRAKADET C        2
# 431  24.0        PRAKADET C        2
# 433  28.0        PRAKADET C        2
# 434  28.0        PRAKADET C        2
# 459  36.0        PRAKADET C        2
# 462  29.0        PRAKADET C        2
# 463  32.0        PRAKADET C        2
# 469  30.0        PRAKADET C        2
# 470  35.0        PRAKADET C        2
# 530  35.0        PRAKADET C        2
# 531  29.0        PRAKADET C        2
# 537  37.0        PRAKADET C        2

# %% [markdown]
# ### 2. PEREMPUAN

# %%
prakadet_c_pr = df[(df['KATEGORI FESTIVAL'] == 'PRAKADET C') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'PRAKADET C' Perempuan: {len(prakadet_c_pr)}")
# Out:
# Jumlah peserta di kategori 'PRAKADET C' Perempuan: 27

# %%
prakadet_c_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Prakadet C Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = prakadet_c_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Prakadet C Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  54.000000            NaN
# 1   2  21.797971      32.202029
# 2   3  11.822477       9.975494
# 3   4   7.673616       4.148860
# 4   5   5.976507       1.697109
# 5   6   4.315998       1.660509
# 6   7   3.777872       0.538126
# 7   8   3.021290       0.756582
# 8   9   2.506437       0.514853
# 9  10   2.093934       0.412502

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
prakadet_c_pr_clustered = prakadet_c_pr.copy()
prakadet_c_pr_clustered['cluster'] = labels

for cluster_label in sorted(prakadet_c_pr_clustered['cluster'].unique()):
    cluster_data = prakadet_c_pr_clustered[prakadet_c_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(prakadet_c_pr_clustered[prakadet_c_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                CLUB                          NAMA  TAHUN L/P     TB    BB  \
# 42        MAVERICKS             MELATI QUEN MALAU   2013   P  130.0  24.0
# 46        MAVERICKS           ELIF CESYA SIHOTANG   2014   P  135.0  28.0
# 126    TI BATU BARA  MEILITKA MEHULIKA BR GINTING   2014   P  130.0  30.0
# 200     ALAM LEUSER       YUMNA SHIDQIYYAH RAHMAN   2013   P  133.0  24.0
# 385     PAB SAENTIS            AIRY BUNGA CANTIKA   2014   P  134.0  26.0
# 388     PAB SAENTIS                IZZAH INSYIRAH   2013   P  128.0  28.0
# 413  UNPRI TKD CLUB        Medina Syahira Habibah   2013   P  124.0  25.0
# 432    TBBC BELAWAN         ALINKA YUAN SYAHPUTRI   2013   P  136.0  26.0
#
#     KATEGORI FESTIVAL  cluster
# 42         PRAKADET C        0
# 46         PRAKADET C        0
# 126        PRAKADET C        0
# 200        PRAKADET C        0
# 385        PRAKADET C        0
# 388        PRAKADET C        0
# 413        PRAKADET C        0
# 432        PRAKADET C        0
#
# Cluster 2:
#               CLUB                      NAMA  TAHUN L/P     TB    BB  \
# 3       ZTC BINJAI             AISYAH AQILLA   2013   P  149.0  49.0
# 39       MAVERICKS          YOHANA TOGATOROP   2013   P  140.0  48.0
# 40       MAVERICKS  NASRO FRANSISKA SIHOTANG   2013   P  143.0  45.0
# 138  RAJAWALI CLUB  Aqila Farahnisa Pasaribu   2013   P  155.0  49.0
# 337        SB CLUB            WIDYA SYAKIRAH   2013   P  152.0  56.0
# 363            PTA       CATARINA SITANGGANG   2013   P  146.0  44.0
# 389    PAB SAENTIS      FAKHIRA AMIRATUSYIFA   2013   P  150.0  37.0
#
#     KATEGORI FESTIVAL  cluster
# 3          PRAKADET C        1
# 39         PRAKADET C        1
# 40         PRAKADET C        1
# 138        PRAKADET C        1
# 337        PRAKADET C        1
# 363        PRAKADET C        1
# 389        PRAKADET C        1
#
# Cluster 3:
#                       CLUB                           NAMA  TAHUN L/P     TB  \
# 22   HTC PUTRA JAYA STABAT       CHELSEA MEISIA BR MARBUN   2013   P  140.0
# 43               MAVERICKS          FELICIA INEZ SIMAMORA   2013   P  141.0
# 44               MAVERICKS            KHALISA YUMMA CAPAH   2014   P  139.0
# 73               HIRMAT TC  Arkana Sachi Al-Faqih Harahap   2014   P  138.0
# 94                    KTTC   ANNABELLA  KYLIE LIAURENCIUS   2013   P  140.0
# 172     RAI TAEKWONDO TEAM      Hanna Shahirah Hutahayan    2013   P  140.0
# 344         Golden Warrior     Ain Aulia Br Perangi-angin   2014   P  144.0
# 386            PAB SAENTIS         MARSYA ZAFIRAH FATHIHA   2013   P  140.0
# 387            PAB SAENTIS                  NAZLAH AMELIA   2013   P  144.0
# 415         UNPRI TKD CLUB                Naomi Dea Barus   2013   P  140.0
# 424               JOHOR TC             Alya Najwa Kamilah   2013   P  140.0
# 429           TBBC BELAWAN               MUZDHALIFA ZAHRA   2014   P  140.0
#
#        BB KATEGORI FESTIVAL  cluster
# 22   30.0        PRAKADET C        2
# 43   30.0        PRAKADET C        2
# 44   30.0        PRAKADET C        2
# 73   29.0        PRAKADET C        2
# 94   40.0        PRAKADET C        2
# 172  30.0        PRAKADET C        2
# 344  33.0        PRAKADET C        2
# 386  33.0        PRAKADET C        2
# 387  33.0        PRAKADET C        2
# 415  35.0        PRAKADET C        2
# 424  40.0        PRAKADET C        2
# 429  26.0        PRAKADET C        2

# %% [markdown]
# ### **KADET**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
kadet_lk = df[(df['KATEGORI FESTIVAL'] == 'KADET') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'KADET' Laki-laki: {len(kadet_lk)}")
# Out:
# Jumlah peserta di kategori 'KADET' Laki-laki: 88

# %%
kadet_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Kadet Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = kadet_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Kadet Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k         SSE  Penurunan_SSE
# 0   1  176.000000            NaN
# 1   2   77.662576      98.337424
# 2   3   50.458906      27.203670
# 3   4   37.701998      12.756908
# 4   5   30.031135       7.670863
# 5   6   26.104690       3.926445
# 6   7   21.683046       4.421644
# 7   8   17.855180       3.827865
# 8   9   14.781069       3.074112
# 9  10   13.124439       1.656629

# %%
k_manual = 4
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
kadet_lk_clustered = kadet_lk.copy()
kadet_lk_clustered['cluster'] = labels

for cluster_label in sorted(kadet_lk_clustered['cluster'].unique()):
    cluster_data = kadet_lk_clustered[kadet_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(kadet_lk_clustered[kadet_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                          CLUB                                  NAMA  TAHUN  \
# 13                 ZTC BINJAI                    EVAN SATRIA BANGUN   2012
# 51                  MAVERICKS                   TRISTAN SIMORANGKIR   2010
# 84                     HASAKU       MUHAMMAD FATIR RIZAL RAIS DAYLI   2010
# 85                     HASAKU                  IMAM PRASETYO JAHARI   2010
# 110            Durin tonggal                       Felix Christian    2011
# 114  Ar-rahman Taekwondo Club                  Alvaro Edgina Winata   2011
# 127              TI BATU BARA                        GILANG PRABOWO   2011
# 150                MTC SERGAI                  ZEZY ALWIANSYAH AZRI   2010
# 176        RAI TAEKWONDO TEAM               Jefri  Efraim Sibarani    2012
# 192     Kazoku Taekwondo Team                         Galih Affandy   2010
# 193     Kazoku Taekwondo Team                          Akhdan Rafif   2010
# 207               ALAM LEUSER                   M.ZAIFATULLAH AKBAR   2010
# 237     TIGER SUMATERA BINJAI               ALDO MERYICLE SEMBIRING   2010
# 238     TIGER SUMATERA BINJAI                 DIRA AGUSTIAN SIREGAR   2010
# 241     TIGER SUMATERA BINJAI                       PUTRA SEMBIRING   2010
# 242     TIGER SUMATERA BINJAI                   M RIAN ARIH GINTING   2010
# 243     TIGER SUMATERA BINJAI            FAHRRUL BAYHAQI NAINGGOLAN   2011
# 246     TIGER SUMATERA BINJAI                         BERIL GABRIEL   2010
# 295        SIBAYAK LIONS CLUB                          ALDEN BERUTU   2010
# 297        SIBAYAK LIONS CLUB                  KARLOS BREMA TARIGAN   2010
# 298        SIBAYAK LIONS CLUB     MESSIAS BINTANG  SAKTI  PANJAITAN   2011
# 299        SIBAYAK LIONS CLUB             BUNGARAN JONATAN SIMAMORA   2010
# 300        SIBAYAK LIONS CLUB                  AMRI GHANI HASIBUAN    2012
# 338                   SB CLUB                    AZKA IBRA NASUTION   2012
# 345                  AL-USWAH                           ZAID ARFHAM   2010
# 346                  AL-USWAH                     BASTIAN AHMADIKA    2011
# 349                  AL-USWAH                        M.RIFQI DANIEL   2010
# 350                  AL-USWAH                      M.OZIKRY MUJAHID   2010
# 351                  AL-USWAH                    M.FADLAN AL HAFIZI   2011
# 352                  AL-USWAH                  IRHAM MAULANA ARFATH   2011
# 374          Simpang Selayang             Aaron Frans Brepin Pandia   2012
# 396               PAB SAENTIS           LOUIS J. VALENTINO SITOHANG   2011
# 425                  JOHOR TC               Fariz Muhammad Hasibuan   2011
# 515                  MIKRONOM                       Immanuel Tambun   2010
# 540                  MIKRONOM  Yohanes Christian Junior Simanjuntak   2010
#
#     L/P     TB    BB KATEGORI FESTIVAL  cluster
# 13    L  151.0  49.0             KADET        0
# 51    L  160.0  53.0             KADET        0
# 84    L  160.0  49.0             KADET        0
# 85    L  158.0  53.0             KADET        0
# 110   L  150.0  49.0             KADET        0
# 114   L  157.0  45.0             KADET        0
# 127   L  162.0  49.0             KADET        0
# 150   L  162.0  45.0             KADET        0
# 176   L  160.0  48.0             KADET        0
# 192   L  163.0  49.0             KADET        0
# 193   L  163.0  53.0             KADET        0
# 207   L  168.0  49.0             KADET        0
# 237   L  159.0  53.0             KADET        0
# 238   L  159.0  45.0             KADET        0
# 241   L  162.0  45.0             KADET        0
# 242   L  164.0  45.0             KADET        0
# 243   L  158.0  41.0             KADET        0
# 246   L  161.0  45.0             KADET        0
# 295   L  158.0  43.0             KADET        0
# 297   L  160.0  48.0             KADET        0
# 298   L  165.0  49.0             KADET        0
# 299   L  160.0  51.0             KADET        0
# 300   L  159.0  53.0             KADET        0
# 338   L  153.0  46.0             KADET        0
# 345   L  156.0  40.0             KADET        0
# 346   L  160.0  46.0             KADET        0
# 349   L  150.0  47.0             KADET        0
# 350   L  150.0  45.0             KADET        0
# 351   L  156.0  45.0             KADET        0
# 352   L  158.0  42.0             KADET        0
# 374   L  155.0  44.0             KADET        0
# 396   L  157.0  41.0             KADET        0
# 425   L  145.0  50.0             KADET        0
# 515   L  152.0  53.0             KADET        0
# 540   L  150.0  51.0             KADET        0
#
# Cluster 2:
#                       CLUB                         NAMA  TAHUN L/P     TB  \
# 17              ZTC BINJAI        FECHDRI AGINA SIREGAR   2012   L  150.0
# 18              ZTC BINJAI       CHRISKI ANANTA SIREGAR   2011   L  152.0
# 52               MAVERICKS              PETRA SIHOMBING   2012   L  140.0
# 55               MAVERICKS         KEVIN WILLIAM SINAGA   2012   L  144.0
# 74               HIRMAT TC       Muhammad Afas Ramadhan   2011   L  149.0
# 128           TI BATU BARA            FAIZ RIZKY ANANDA   2011   L  144.0
# 139          RAJAWALI CLUB   Steven Imanuel Lumban Gaol   2012   L  141.0
# 151             MTC SERGAI         MUHAMMAD IKROM LUBIS   2010   L  148.0
# 153             MTC SERGAI         JOEL TOBIAS SIBURIAN   2010   L  154.0
# 191  Kazoku Taekwondo Team                    Geo Dzaki   2011   L  140.0
# 239  TIGER SUMATERA BINJAI        RADITYA ZAHRAN KHAIRY   2011   L  152.0
# 240  TIGER SUMATERA BINJAI       HAFIZH MARSYA RAMADHAN   2011   L  142.0
# 244  TIGER SUMATERA BINJAI        AHMAD AL FATIH ARIFIN   2012   L  145.0
# 263    Badar Nurul Iman TC               IMAM ZUL HAIRI   2011   L  148.0
# 347               AL-USWAH       SENJA LUCKY ALVIANSYAH   2011   L  149.0
# 348               AL-USWAH     M NIZAM RAMADHAN SIREGAR   2011   L  149.0
# 393            PAB SAENTIS   VIKTOR DAVIDSON IDOANJU S.   2010   L  145.0
# 394            PAB SAENTIS  CHELVIN HILTON CRISTOVEL S.   2010   L  140.0
# 395            PAB SAENTIS             AL HAKIM GIFHARI   2011   L  150.0
# 435           TBBC BELAWAN              HAFIZ HIZBULLAH   2010   L  153.0
# 437           TBBC BELAWAN                  CHAIDIR ALI   2011   L  139.0
# 438           TBBC BELAWAN       REZKY NAFA LUTFIL HADI   2012   L  151.0
# 538               MIKRONOM               Nicholas Kosim   2012   L  140.0
# 539               MIKRONOM         Devon Lowell Ghozali   2010   L  145.0
# 549               MIKRONOM          PASCAL HOSEA SILAEN   2012   L  143.0
#
#        BB KATEGORI FESTIVAL  cluster
# 17   37.0             KADET        1
# 18   37.0             KADET        1
# 52   41.0             KADET        1
# 55   30.0             KADET        1
# 74   37.0             KADET        1
# 128  45.0             KADET        1
# 139  34.0             KADET        1
# 151  45.0             KADET        1
# 153  36.0             KADET        1
# 191  37.0             KADET        1
# 239  33.0             KADET        1
# 240  37.0             KADET        1
# 244  45.0             KADET        1
# 263  37.0             KADET        1
# 347  29.0             KADET        1
# 348  30.0             KADET        1
# 393  37.0             KADET        1
# 394  37.0             KADET        1
# 395  41.0             KADET        1
# 435  33.0             KADET        1
# 437  37.0             KADET        1
# 438  37.0             KADET        1
# 538  42.0             KADET        1
# 539  47.0             KADET        1
# 549  38.0             KADET        1
#
# Cluster 3:
#                       CLUB                           NAMA  TAHUN L/P     TB  \
# 24   HTC PUTRA JAYA STABAT        Sinar Husni Adi Siregar   2011   L  170.0
# 61           SMPN 8 BINJAI   JOSUA RENGGA PRATAMA HUTAPEA   2010   L  168.0
# 154             MTC SERGAI  BINTANG ALMUTADIBILLAH SAGALA   2010   L  160.0
# 157    ROYAL SUMATERA TEAM                        RIVALDI   2008   L  176.0
# 158    ROYAL SUMATERA TEAM                 ABDILLAH HANIF   2011   L  169.0
# 194  Kazoku Taekwondo Team            Syeilendra Abimanyu   2010   L  163.0
# 245  TIGER SUMATERA BINJAI             ABDI NUGRAHA LUBIS   2010   L  158.0
# 247  TIGER SUMATERA BINJAI                   FAHRI B AGMA   2010   L  165.0
# 248  TIGER SUMATERA BINJAI        MIKHAEL CHRISTIAN PURBA   2011   L  164.0
# 301     SIBAYAK LIONS CLUB      BENYAMIN MALAKI SUMANDORO   2012   L  145.0
# 373       Simpang Selayang       Immanuel Bastanta Pandia   2012   L  150.0
# 397            PAB SAENTIS                    REZA HAIKAL   2011   L  163.0
# 447              GASS TEAM         MARVEL MORANO PARDOSI    2012   L  165.0
# 448              GASS TEAM        TRISTAN GABRIEL TARIGAN   2011   L  168.0
# 466                    GSM                          REVAN   2010   L  175.0
# 507               MIKRONOM        Dalmin Karim Aldimen. L   2010   L  169.0
#
#        BB KATEGORI FESTIVAL  cluster
# 24   61.0             KADET        2
# 61   64.1             KADET        2
# 154  57.0             KADET        2
# 157  73.0             KADET        2
# 158  61.0             KADET        2
# 194  65.0             KADET        2
# 245  65.0             KADET        2
# 247  65.0             KADET        2
# 248  57.0             KADET        2
# 301  64.0             KADET        2
# 373  65.0             KADET        2
# 397  56.0             KADET        2
# 447  58.0             KADET        2
# 448  62.0             KADET        2
# 466  55.0             KADET        2
# 507  70.0             KADET        2
#
# Cluster 4:
#                    CLUB                           NAMA  TAHUN L/P     TB  \
# 54            MAVERICKS           LEONEL SABAM SIAHAAN   2012   L  131.0
# 58    FATHUR-RAHMAN TKD                   TEGUH WIJAYA   2012   L  135.0
# 109       Durin tonggal            Tobi Prima Ginting    2012   L  135.0
# 111      Durin tonggal           Steven Fajar Tarigan    2012   L  133.0
# 152          MTC SERGAI              MARIO OMPU SUNGGU   2010   L  110.0
# 174  RAI TAEKWONDO TEAM  Joenathan Chirtian Panjaitan    2011   L  135.0
# 292  SIBAYAK LIONS CLUB             M. BAGUS ALFAYYADH   2011   L  138.0
# 293  SIBAYAK LIONS CLUB       ALVONSO GEBIENSA GINTING   2012   L  125.0
# 294  SIBAYAK LIONS CLUB                      SAIFULLAH   2011   L  135.0
# 296  SIBAYAK LIONS CLUB               SIMON SINABARIBA   2010   L  130.0
# 392         PAB SAENTIS       STIVEN RIZKI SIMANJUNTAK   2012   L  130.0
# 547            MIKRONOM                  RODO PASARIBU   2011   L  133.0
#
#        BB KATEGORI FESTIVAL  cluster
# 54   33.0             KADET        3
# 58   40.0             KADET        3
# 109  49.0             KADET        3
# 111  33.0             KADET        3
# 152  33.0             KADET        3
# 174  33.0             KADET        3
# 292  30.0             KADET        3
# 293  33.0             KADET        3
# 294  33.0             KADET        3
# 296  45.0             KADET        3
# 392  33.0             KADET        3
# 547  35.0             KADET        3

# %% [markdown]
# ### 2. PEREMPUAN

# %%
kadet_pr = df[(df['KATEGORI FESTIVAL'] == 'KADET') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'Kadet' Perempuan: {len(kadet_pr)}")
# Out:
# Jumlah peserta di kategori 'Kadet' Perempuan: 66

# %%
kadet_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Kadet Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = kadet_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Kadet Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k         SSE  Penurunan_SSE
# 0   1  132.000000            NaN
# 1   2   60.221956      71.778044
# 2   3   36.723936      23.498020
# 3   4   25.103875      11.620061
# 4   5   18.901773       6.202102
# 5   6   16.117033       2.784741
# 6   7   13.523733       2.593299
# 7   8   11.166804       2.356929
# 8   9    9.581955       1.584849
# 9  10    8.140019       1.441936

# %%
k_manual = 4
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
kadet_pr_clustered = kadet_pr.copy()
kadet_pr_clustered['cluster'] = labels

for cluster_label in sorted(kadet_pr_clustered['cluster'].unique()):
    cluster_data = kadet_pr_clustered[kadet_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(kadet_pr_clustered[kadet_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                            CLUB                          NAMA  TAHUN L/P  \
# 10                   ZTC BINJAI         DEARTY TABITHA TOBING   2011   P
# 11                   ZTC BINJAI         FERLITA NURAINI AUZIA   2010   P
# 12                   ZTC BINJAI  STEVANY PEBINA BR. SEMBIRING   2012   P
# 14                   ZTC BINJAI        IRIYEL SURAMANA SITEPU   2010   P
# 63                SMPN 8 BINJAI               MONICA ANDRIANI   2010   P
# 129                TI BATU BARA                INAYAH FAHIRAH   2011   P
# 130                TI BATU BARA               CUT SRI UMAYYAH   2011   P
# 142               RAJAWALI CLUB                  Savana Putri   2012   P
# 175          RAI TAEKWONDO TEAM          Indira Dwi Natasya     2011   P
# 187             GRETT INDONESIA                  PUAN SADJADU   2010   P
# 198       Kazoku Taekwondo Team           Kayla Agus Ramadani   2010   P
# 206                 ALAM LEUSER         NAYSA NATHANIA BANGUN   2011   P
# 251       TIGER SUMATERA BINJAI              AURA DIVA KUSERA   2010   P
# 266  WOLF REBORN TAEKWONDO TEAM          REHULINA Br SIPAYUNG   2011   P
# 274           UKM TAEKWONDO USU                 NASRIN AHMADI   2008   P
# 404                 PAB SAENTIS               AISYAH SHAHIRAH   2010   P
# 440                TBBC BELAWAN         NAOMI SHAKILA HIDAYAT   2012   P
# 552                    MIKRONOM               Aulia Hutabarat   2011   P
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 10   158.0  51.0             KADET        0
# 11   151.0  51.0             KADET        0
# 12   154.0  59.0             KADET        0
# 14   160.0  47.0             KADET        0
# 63   154.0  50.2             KADET        0
# 129  157.0  47.0             KADET        0
# 130  155.0  51.0             KADET        0
# 142  152.0  52.0             KADET        0
# 175  153.0  49.0             KADET        0
# 187  153.0  50.0             KADET        0
# 198  150.0  55.0             KADET        0
# 206  160.0  47.0             KADET        0
# 251  157.0  51.0             KADET        0
# 266  150.0  51.0             KADET        0
# 274  156.0  52.0             KADET        0
# 404  154.0  47.0             KADET        0
# 440  147.0  55.0             KADET        0
# 552  150.0  53.0             KADET        0
#
# Cluster 2:
#                       CLUB                            NAMA  TAHUN L/P     TB  \
# 53               MAVERICKS                    XENA ZENIATI   2012   P  140.0
# 102  TAEKWONDO GOLDEN STAR  T SHAHNAZ QORY FITHRAH N K L F   2012   P  135.0
# 162        KHENZUA FIGHTER                 RHACELLA MAUREN   2012   P  145.0
# 203            ALAM LEUSER                  NABILA SAFIRA    2011   P  143.0
# 249  TIGER SUMATERA BINJAI         MUMTAZA KIRAN ASSYAKILA   2012   P  135.0
# 270    Champion Fighter TC                      Nurul Aini   2010   P  140.0
# 302     SIBAYAK LIONS CLUB                   ANGGIE SINAGA   2010   P  140.0
# 398            PAB SAENTIS                SYAHBILA KARTIKA   2010   P  142.0
# 399            PAB SAENTIS                   NURUL SABRINA   2012   P  140.0
# 436           TBBC BELAWAN     ASYIFA AZRINKA PUTRI JAM'AS   2011   P  139.0
# 439           TBBC BELAWAN               KEISYA ARNINDHITA   2011   P  145.0
# 464                    GSM       AXELIA GASHANI DARA PUTRI   2012   P  144.0
# 465                    GSM    ZHIVANA KAWURI PUTRI TUNGGAL   2011   P  145.0
#
#        BB KATEGORI FESTIVAL  cluster
# 53   29.0             KADET        1
# 102  29.0             KADET        1
# 162  37.0             KADET        1
# 203  33.0             KADET        1
# 249  37.0             KADET        1
# 270  41.0             KADET        1
# 302  42.0             KADET        1
# 398  37.0             KADET        1
# 399  37.0             KADET        1
# 436  37.0             KADET        1
# 439  29.0             KADET        1
# 464  37.0             KADET        1
# 465  35.0             KADET        1
#
# Cluster 3:
#                       CLUB                             NAMA  TAHUN L/P     TB  \
# 9               ZTC BINJAI               AURELA KARINA BABA   2011   P  150.0
# 83                  HASAKU       JOCELYN ARTHALITA BR KABAN   2012   P  150.0
# 96                    KTTC            ASSYLA QANITAH ANANDA   2012   P  156.0
# 140          RAJAWALI CLUB             Ester Debora Tarigan   2010   P  156.0
# 141          RAJAWALI CLUB          Cindi Setepani Tambunan   2012   P  151.0
# 148             MTC SERGAI           HILDA SYAFALMA DIRADHA   2011   P  148.0
# 149             MTC SERGAI  STEVEN PEBRIO NAMORA HUTAGALUNG   2011   P  155.0
# 173     RAI TAEKWONDO TEAM         Sepania Miranda Silalahi   2012   P  150.0
# 188        GRETT INDONESIA                       NADA AULIA   2010   P  151.0
# 195  Kazoku Taekwondo Team          Keyla Aprilia Sembiring   2010   P  150.0
# 196  Kazoku Taekwondo Team                  Audria Fitaloka   2010   P  155.0
# 197  Kazoku Taekwondo Team                  Tania Fara Diba   2010   P  155.0
# 204            ALAM LEUSER         MUSHOFIA KHAIRIYAH THOZI   2010   P  150.0
# 205            ALAM LEUSER    KHAIRIZA ARVA PUTRI SEMBIRING   2010   P  148.0
# 250  TIGER SUMATERA BINJAI         EMIA ABIGAEL BR SURBAKTI   2010   P  158.0
# 400            PAB SAENTIS           TSARWAH MUTIARA ATSANI   2012   P  150.0
# 401            PAB SAENTIS                      PUTRI UTAMI   2011   P  150.0
# 402            PAB SAENTIS             RAHMA NAIFAH SIREGAR   2011   P  159.0
# 403            PAB SAENTIS                   RASYIKA NOZORA   2012   P  148.0
# 405            PAB SAENTIS    SYABRINA NESYA KHIARA HARAPAN   2012   P  150.0
# 416         UNPRI TKD CLUB                    Melati Umaira   2012   P  153.0
# 449              GASS TEAM        ANGRENI MARIA G SIMBOLON    2010   P  148.0
# 451              GASS TEAM                     KANAYA PUTRI   2010   P  153.0
# 452              GASS TEAM               AULIA NUR  ASHIFAH   2010   P  150.0
# 551               MIKRONOM           Wanti Octaviany Haloho   2011   P  155.0
#
#        BB KATEGORI FESTIVAL  cluster
# 9    44.0             KADET        2
# 83   41.0             KADET        2
# 96   40.0             KADET        2
# 140  44.0             KADET        2
# 141  37.0             KADET        2
# 148  42.0             KADET        2
# 149  43.0             KADET        2
# 173  37.0             KADET        2
# 188  39.0             KADET        2
# 195  37.0             KADET        2
# 196  41.0             KADET        2
# 197  44.0             KADET        2
# 204  37.0             KADET        2
# 205  42.0             KADET        2
# 250  41.0             KADET        2
# 400  41.0             KADET        2
# 401  44.0             KADET        2
# 402  44.0             KADET        2
# 403  45.0             KADET        2
# 405  47.0             KADET        2
# 416  42.0             KADET        2
# 449  47.0             KADET        2
# 451  44.0             KADET        2
# 452  45.0             KADET        2
# 551  42.0             KADET        2
#
# Cluster 4:
#                       CLUB                               NAMA  TAHUN L/P  \
# 15              ZTC BINJAI               RAESA AMANDA GINTING   2010   P
# 23   HTC PUTRA JAYA STABAT                   Raisa Br. Bangun   2010   P
# 25   HTC PUTRA JAYA STABAT  Naomi Magdalena Asima simanjuntak   2010   P
# 62           SMPN 8 BINJAI            EMIA JULITA Br. GINTING   2010   P
# 163        KHENZUA FIGHTER                   BUNGA VHALINDCIA   2010   P
# 208            ALAM LEUSER              JESICA CALISTA BANGUN   2010   P
# 275      UKM TAEKWONDO USU                    ROQHAIAH NAZARI   2010   P
# 406            PAB SAENTIS                DUWI OCTAVIA RAHAYU   2011   P
# 450              GASS TEAM                 MELISA ARTA BANGUN   2010   P
# 553               MIKRONOM                       Alwyna Purba   2011   P
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 15   164.0  47.0             KADET        3
# 23   166.0  59.0             KADET        3
# 25   165.0  59.0             KADET        3
# 62   160.0  56.1             KADET        3
# 163  162.0  60.0             KADET        3
# 208  165.0  59.0             KADET        3
# 275  161.0  52.0             KADET        3
# 406  160.0  55.0             KADET        3
# 450  163.0  59.0             KADET        3
# 553  159.0  58.0             KADET        3

# %% [markdown]
# ### **JUNIOR**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
junior_lk = df[(df['KATEGORI FESTIVAL'] == 'JUNIOR') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'JUNIOR' Laki-laki: {len(junior_lk)}")
# Out:
# Jumlah peserta di kategori 'JUNIOR' Laki-laki: 75

# %%
junior_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Junior Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = junior_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Junior Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k         SSE  Penurunan_SSE
# 0   1  150.000000            NaN
# 1   2   67.473237      82.526763
# 2   3   43.949622      23.523615
# 3   4   34.191488       9.758134
# 4   5   27.832555       6.358934
# 5   6   20.566080       7.266475
# 6   7   17.157050       3.409031
# 7   8   14.910369       2.246680
# 8   9   13.252878       1.657491
# 9  10   11.852547       1.400331

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
junior_lk_clustered = junior_lk.copy()
junior_lk_clustered['cluster'] = labels

for cluster_label in sorted(junior_lk_clustered['cluster'].unique()):
    cluster_data = junior_lk_clustered[junior_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(junior_lk_clustered[junior_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                       CLUB                                NAMA  TAHUN L/P  \
# 28           TKD GOR Dairi         Arnold septiawan ompusunggu   2007   L
# 29           TKD GOR Dairi             Tiras Wijaya Sembiring    2009   L
# 30           TKD GOR Dairi                 Hagai lumban tobing   2009   L
# 31           TKD GOR Dairi             William supratno berutu   2007   L
# 64           SMPN 8 BINJAI                   DECO DWI ALANSYAH   2007   L
# 67          PETARUNG 0206   GABRIEL CHRISTIAN ARIESTA SITOMPUL   2009   L
# 68          PETARUNG 0206                    TAMBOK HM GURNING   2009   L
# 69          PETARUNG 0206          MARUBA PARDINGOTAN KUDADIRI   2007   L
# 88                  HASAKU              RICHARD ALFREDO SIRAIT   2009   L
# 89                  HASAKU                              ARJUNA   2008   L
# 105  TAEKWONDO GOLDEN STAR                AKEYLA LUTHFI SYAFIQ   2009   L
# 118   Stosa Taekwondo Club              Don juan A. Sitanggang   2009   L
# 119   Stosa Taekwondo Club          Pahala Ignatius Sitanggang   2009   L
# 143          RAJAWALI CLUB          Janberisco Romualdus Manik   2009   L
# 155             MTC SERGAI               FAISAL GHAZALI SAGALA   2009   L
# 182     RAI TAEKWONDO TEAM                 Ramzy Ananda Pohan    2008   L
# 210            ALAM LEUSER                     JUANDRA PRASTIO   2009   L
# 254  TIGER SUMATERA BINJAI              AHMAD MAULANA NASUTION   2009   L
# 272                R.A ONE                          ARRAJASYAH   2008   L
# 303     SIBAYAK LIONS CLUB                     FACHRIAL HANAFI   2007   L
# 308     SIBAYAK LIONS CLUB              JULIUS PEDRO SIMAMORA    2008   L
# 311     SIBAYAK LIONS CLUB                      ADRIAN BASTOTO   2008   L
# 316     SIBAYAK LIONS CLUB                 BREMADANI SEMBIRING   2007   L
# 353               AL-USWAH                RIDHO PRISMA SIREGAR   2008   L
# 354               AL-USWAH                      AZWAR RADHILAH   2008   L
# 360               AL-USWAH            Ranaldi Ecan PRATAMA SBR   2007   L
# 407            PAB SAENTIS             PRAYOGA SAPUTRA LIMBONG   2009   L
# 454              GASS TEAM                               RIDHO   2009   L
# 508               MIKRONOM        Jeremian Didascou Sitanggang   2007   L
# 509               MIKRONOM                      Rafael Sitorus   2003   L
# 523               MIKRONOM              Jeafer Alexander Thiam   2009   L
# 541               MIKRONOM                  Joy Yakin Pasaribu   2007   L
# 542               MIKRONOM                        Aditya Rafqy   2006   L
# 550               MIKRONOM                  Baginda ButarButar   2008   L
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 28   164.0  51.0            JUNIOR        0
# 29   165.0  48.0            JUNIOR        0
# 30   165.0  51.0            JUNIOR        0
# 31   167.0  59.0            JUNIOR        0
# 64   168.0  52.9            JUNIOR        0
# 67   163.0  54.0            JUNIOR        0
# 68   165.0  58.0            JUNIOR        0
# 69   162.0  60.0            JUNIOR        0
# 88   168.0  51.0            JUNIOR        0
# 89   168.0  59.0            JUNIOR        0
# 548               MIKRONOM               ORVIN PASARIBU   2010   L  158.0
#
#        BB KATEGORI FESTIVAL  cluster
# 27   45.0            JUNIOR        1
# 87   48.0            JUNIOR        1
# 180  45.0            JUNIOR        1
# 181  48.0            JUNIOR        1
# 252  48.0            JUNIOR        1
# 253  55.0            JUNIOR        1
# 256  45.0            JUNIOR        1
# 278  48.0            JUNIOR        1
# 304  45.0            JUNIOR        1
# 305  48.0            JUNIOR        1
# 306  50.0            JUNIOR        1
# 307  51.0            JUNIOR        1
# 309  52.0            JUNIOR        1
# 310  52.0            JUNIOR        1
# 312  54.0            JUNIOR        1
# 313  55.0            JUNIOR        1
# 314  55.0            JUNIOR        1
# 315  57.0            JUNIOR        1
# 317  58.0            JUNIOR        1
# 355  48.0            JUNIOR        1
# 356  50.0            JUNIOR        1
# 357  58.0            JUNIOR        1
# 359  45.0            JUNIOR        1
# 442  55.0            JUNIOR        1
# 548  43.0            JUNIOR        1
#
# Cluster 3:
#                       CLUB                            NAMA  TAHUN L/P     TB  \
# 115   Stosa Taekwondo Club  Joel Ishak Hamonangan Silalahi   2008   L  169.0
# 116   Stosa Taekwondo Club           Daniel Arapenta Pinem   2008   L  174.0
# 117   Stosa Taekwondo Club        Malvyn Mackenzy Menachem   2008   L  172.0
# 131           TI BATU BARA              ALFARIZI RIZQULLAH   2009   L  165.0
# 159    ROYAL SUMATERA TEAM           MUHAMMAD FADLIN AZIMA   2007   L  175.0
# 179     RAI TAEKWONDO TEAM          Raditya Raffi Rinaldi    2008   L  170.0
# 183     RAI TAEKWONDO TEAM           Ilham Lutfi Sipahutar   2009   L  173.0
# 255  TIGER SUMATERA BINJAI              JUAN FELIX TARIGAN   2007   L  178.0
# 277      UKM TAEKWONDO USU              ALDY PRATAMA PINEM   2007   L  175.0
# 358               AL-USWAH                  M ALIF LAM MIM   2007   L  158.0
# 455              GASS TEAM            JORDAN ALASKA BANGUN   2007   L  172.0
# 510               MIKRONOM                    Very Chandra   2007   L  179.0
# 512               MIKRONOM                   Patrick Shira   2007   L  178.0
# 513               MIKRONOM                         Chelsen   2007   L  167.0
# 521               MIKRONOM          Benaya Eliezer Siadari   2009   L  172.0
# 522               MIKRONOM                   Alvin Anggara   2009   L  171.0
#
#        BB KATEGORI FESTIVAL  cluster
# 115  70.0            JUNIOR        2
# 116  64.0            JUNIOR        2
# 117  85.0            JUNIOR        2
# 131  78.0            JUNIOR        2
# 159  69.0            JUNIOR        2
# 179  85.0            JUNIOR        2
# 183  78.0            JUNIOR        2
# 255  59.0            JUNIOR        2
# 277  77.0            JUNIOR        2
# 358  80.0            JUNIOR        2
# 455  67.0            JUNIOR        2
# 510  90.0            JUNIOR        2
# 512  76.5            JUNIOR        2
# 513  69.0            JUNIOR        2
# 521  72.3            JUNIOR        2
# 522  69.0            JUNIOR        2

# %% [markdown]
# ### 2. PEREMPUAN

# %%
junior_pr = df[(df['KATEGORI FESTIVAL'] == 'JUNIOR') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'Junior' Perempuan: {len(junior_pr)}")
# Out:
# Jumlah peserta di kategori 'Junior' Perempuan: 39

# %%
junior_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Junior Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = junior_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Junior Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  78.000000            NaN
# 1   2  40.216209      37.783791
# 2   3  23.592711      16.623498
# 3   4  18.095656       5.497055
# 4   5  12.719101       5.376555
# 5   6  10.095970       2.623131
# 6   7   8.093007       2.002963
# 7   8   6.510932       1.582075
# 8   9   5.520680       0.990252
# 9  10   4.541974       0.978707

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
junior_pr_clustered = junior_pr.copy()
junior_pr_clustered['cluster'] = labels

for cluster_label in sorted(junior_pr_clustered['cluster'].unique()):
    cluster_data = junior_pr_clustered[junior_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(junior_pr_clustered[junior_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                       CLUB                           NAMA  TAHUN L/P     TB  \
# 16              ZTC BINJAI                HARUMI SAHPUTRI   2008   P  155.0
# 32           TKD GOR Dairi  Lastri Roma Arta siringoringo   2008   P  155.0
# 59       FATHUR-RAHMAN TKD            MAULIDZA AYU ANDITA   2009   P  160.0
# 103  TAEKWONDO GOLDEN STAR                   YUS SYAHRANI   2008   P  158.0
# 104  TAEKWONDO GOLDEN STAR                KEYLA ALIF KHAN   2008   P  162.0
#                       CLUB                        NAMA  TAHUN L/P     TB  \
# 26   HTC PUTRA JAYA STABAT       Lawren Ivana Pasaribu   2008   P  160.0
# 33           TKD GOR Dairi            Riesya Salsabila   2007   P  158.0
# 97                    KTTC                 NAZWA FAHRI   2007   P  169.0
# 120         KUTALIMBARU TC  Margareth Clara Br Tarigan   2009   P  164.0
# 121         KUTALIMBARU TC     Marsellita Br Sembiring   2008   P  159.0
# 132           TI BATU BARA       AMIROH YASMIN SIREGAR   2007   P  160.0
# 178     RAI TAEKWONDO TEAM        Siti Azzahra Wibowo    2007   P  162.0
# 209            ALAM LEUSER         ADINDA BR SEMBIRING   2008   P  160.0
# 273                R.A ONE    INDRIA KHAIRUNNISA FAIHA   2009   P  170.0
# 276      UKM TAEKWONDO USU                LAILA NAZARI   2007   P  158.0
#
#        BB KATEGORI FESTIVAL  cluster
# 26   63.0            JUNIOR        2
# 33   59.0            JUNIOR        2
# 97   58.0            JUNIOR        2
# 120  78.0            JUNIOR        2
# 121  62.8            JUNIOR        2
# 132  59.0            JUNIOR        2
# 178  64.0            JUNIOR        2
# 209  59.0            JUNIOR        2
# 273  68.0            JUNIOR        2
# 276  67.0            JUNIOR        2

# %% [markdown]
# ### **SENIOR**

# %% [markdown]
# ### 1. LAKI-LAKI

# %%
senior_lk = df[(df['KATEGORI FESTIVAL'] == 'SENIOR') & (df['L/P'] == 'L')]
print(f"Jumlah peserta di kategori 'SENIOR' Laki-laki: {len(senior_lk)}")
# Out:
# Jumlah peserta di kategori 'SENIOR' Laki-laki: 44

# %%
senior_lk.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Senior Laki-laki')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = senior_lk[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Senior Laki-laki')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  88.000000            NaN
# 1   2  44.929179      43.070821
# 2   3  28.867269      16.061910
# 3   4  20.575835       8.291434
# 4   5  15.890612       4.685223
# 5   6  12.882876       3.007736
# 6   7   9.976187       2.906689
# 7   8   8.393604       1.582583
# 8   9   6.863136       1.530468
# 9  10   5.446953       1.416182

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
senior_lk_clustered = senior_lk.copy()
senior_lk_clustered['cluster'] = labels

for cluster_label in sorted(senior_lk_clustered['cluster'].unique()):
    cluster_data = senior_lk_clustered[senior_lk_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(senior_lk_clustered[senior_lk_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                           CLUB                                NAMA  TAHUN L/P  \
# 66                   FK UNMETH       Jacky Chan Nicholas Hutabarat   2006   L
# 71              PETARUNG 0206               FEBRI VALENTINO MUNTHE   2004   L
# 98            POLTEKBANG MEDAN          RAJA ANANDRA PUTRA GINTING   2004   L
# 101           POLTEKBANG MEDAN            DEVIN FAYZUL HAQ GINTING   2004   L
# 185         RAI TAEKWONDO TEAM              Ahmad Rasya Matondang    2006   L
# 282          UKM TAEKWONDO USU     EZEKIEL ALDRIK SUSILO SIMARMATA   2004   L
# 283          UKM TAEKWONDO USU            LEONARD JHOSUA HUTABARAT   2005   L
# 418             UNPRI TKD CLUB                  Ahmad Yusuf Fauzan   2005   L
# 419             UNPRI TKD CLUB              James Piter Simatupang   2003   L
# 445              Taekwondo UMA                      Rizky Abdillah   2003   L
# 471     HUMAIRA TAEKWONDO CLUB                   M. ADNAN HASIBUAN   2005   L
# 473  Upm.Univ.Panca Budi Medan                               ROHIM   2003   L
# 479                   MIKRONOM                        Nabilly Mara   2004   L
# 483                   MIKRONOM    Samuel Sumegit Bastanta Brahmana   2005   L
# 484                   MIKRONOM        Samuel G. Christian Pakpahan   2003   L
# 487                   MIKRONOM  Muhammad Aura Fiergiansyah Ginting   2005   L
# 488                   MIKRONOM                          Jack Bryan   2004   L
# 491                   MIKRONOM       Isakhar Julio Caesar Sitompul   2005   L
# 496                   MIKRONOM               Monang Soaloon Sirait   2005   L
# 505                   MIKRONOM                     Rafa Al-Faroukh   2006   L
#
#         TB     BB KATEGORI FESTIVAL  cluster
# 66   174.0  73.00            SENIOR        0
# 71   178.0  75.00            SENIOR        0
# 98   176.0  63.00            SENIOR        0
# 101  170.0  67.00            SENIOR        0
# 185  170.0  60.00            SENIOR        0
# 282  171.0  70.00            SENIOR        0
# 283  175.0  73.00            SENIOR        0
# 418  175.0  55.00            SENIOR        0
# 419  170.0  68.00            SENIOR        0
# 445  165.0  74.00            SENIOR        0
# 471  170.0  63.00            SENIOR        0
# 473  173.0  76.00            SENIOR        0
# 479  172.0  76.00            SENIOR        0
# 483  168.0  68.00            SENIOR        0
# 484  170.0  60.45            SENIOR        0
# 487  175.0  77.60            SENIOR        0
# 488  171.0  81.00            SENIOR        0
# 491  170.0  58.00            SENIOR        0
# 496  170.0  62.20            SENIOR        0
# 505  171.0  59.00            SENIOR        0
#
# Cluster 2:
#                              CLUB                       NAMA  TAHUN L/P  \
# 65                      FK UNMETH  Ewaldo Prayoga Nainggolan   2004   L
# 70                 PETARUNG 0206       RANGGA GERALVA TURNIP   2006   L
# 284             UKM TAEKWONDO USU        SAUT MARTUA PARDEDE   2007   L
# 323            SIBAYAK LIONS CLUB                MARCHELLIUS   2004   L
# 329  Universitas Tjut Nyak Dhien            Andrean Harahap    2003   L
# 330  Universitas Tjut Nyak Dhien              Juel Salem Gea   2002   L
# 331  Universitas Tjut Nyak Dhien     Tri Anugrah Syukur Gea    2003   L
# 333  Universitas Tjut Nyak Dhien               Irwan buulolo   2002   L
# 367                         UNIKA              Robertus Alua   2004   L
# 417                UNPRI TKD CLUB        Apit Benaya Ginting   2004   L
# 444                 Taekwondo UMA   Monang Fernando Pasaribu   2005   L
# 472     Upm.Univ.Panca Budi Medan    RAFLES PRASUKI PASARIBU   2002   L
# 476                      MIKRONOM             Aldo Manullang   2004   L
# 477                      MIKRONOM      Andre Daniel Sitinjak   2002   L
# 486                      MIKRONOM             Aldo Sebastian   2003   L
# 489                      MIKRONOM               Ryu Kierando   2005   L
# 490                      MIKRONOM             Vincent Colins   2006   L
# 494                      MIKRONOM              Tengku Farhan   2003   L
# 495                      MIKRONOM       Jonathan Simanjuntak   2004   L
# 504                      MIKRONOM       Lucky Azrarur Rahman   2005   L
# 506                      MIKRONOM         Joshua Simanjuntak   2001   L
#
#         TB    BB KATEGORI FESTIVAL  cluster
# 65   165.0  46.0            SENIOR        1
# 70   167.0  55.0            SENIOR        1
# 284  161.0  48.0            SENIOR        1
# 323  155.0  71.0            SENIOR        1
# 329  165.0  60.0            SENIOR        1
# 330  160.0  53.0            SENIOR        1
# 331  160.0  49.0            SENIOR        1
# 333  160.0  56.0            SENIOR        1
# 367  165.0  65.0            SENIOR        1
# 417  162.0  52.0            SENIOR        1
# 444  165.0  58.0            SENIOR        1
# 472  153.0  53.0            SENIOR        1
# 476  160.0  68.0            SENIOR        1
# 477  163.0  68.0            SENIOR        1
# 486  165.0  63.0            SENIOR        1
# 489  165.0  50.2            SENIOR        1
# 490  162.0  48.0            SENIOR        1
# 494  162.0  47.0            SENIOR        1
# 495  168.0  54.0            SENIOR        1
# 504  165.0  60.0            SENIOR        1
# 506  168.0  53.6            SENIOR        1
#
# Cluster 3:
#                  CLUB                      NAMA  TAHUN L/P     TB     BB  \
# 99   POLTEKBANG MEDAN  FRANSDITO ARYO WICAKSONO   2004   L  180.0   83.0
# 554          MIKRONOM          Kevin Rusvinaldi   2004   L  170.0  115.0
# 555          MIKRONOM     Kaleb Yoan vino purba   2004   L  185.0  105.0
#
#     KATEGORI FESTIVAL  cluster
# 99             SENIOR        2
# 554            SENIOR        2
# 555            SENIOR        2

# %% [markdown]
# ### 2. PEREMPUAN

# %%
senior_pr = df[(df['KATEGORI FESTIVAL'] == 'SENIOR') & (df['L/P'] == 'P')]
print(f"Jumlah peserta di kategori 'Senior' Perempuan: {len(senior_pr)}")
# Out:
# Jumlah peserta di kategori 'Senior' Perempuan: 29

# %%
senior_pr.plot(kind='scatter', x='TB', y='BB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Sebaran Peserta Senior Perempuan')
plt.xlabel('Tinggi Badan (TB)')
plt.ylabel('Berat Badan (BB)')
plt.show()

# %%
X = senior_pr[['TB', 'BB']]
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(range(1, 11), inertia, marker='o')
plt.xticks(range(1, 11))
plt.title('Elbow Method - Senior Perempuan')
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('Sum of Squared Error (SSE)')
plt.show()

# %%
sse_diff = [np.nan] + [inertia[i - 1] - inertia[i] for i in range(1, len(inertia))]
sse_df = pd.DataFrame({
    'k': range(1, len(inertia) + 1),
    'SSE': inertia,
    'Penurunan_SSE': sse_diff
})
print("\nTabel Penurunan SSE:")
print(sse_df)
# Out:
# Tabel Penurunan SSE:
#     k        SSE  Penurunan_SSE
# 0   1  58.000000            NaN
# 1   2  25.724518      32.275482
# 2   3  16.181514       9.543004
# 3   4  11.305686       4.875828
# 4   5   7.719874       3.585813
# 5   6   5.833518       1.886356
# 6   7   4.939463       0.894054
# 7   8   3.767286       1.172178
# 8   9   2.930660       0.836626
# 9  10   2.501234       0.429426

# %%
k_manual = 3
kmeans = KMeans(n_clusters=k_manual, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# Tambahkan hasil klaster ke DataFrame
senior_pr_clustered = senior_pr.copy()
senior_pr_clustered['cluster'] = labels

for cluster_label in sorted(senior_pr_clustered['cluster'].unique()):
    cluster_data = senior_pr_clustered[senior_pr_clustered['cluster'] == cluster_label]

    # Urutkan berdasarkan TB
    cluster_data = cluster_data.sort_values(by='TB').reset_index(drop=True)
    tb_values = cluster_data['TB'].astype(int)
    bb_values = cluster_data['BB'].values

    # Gunakan index sebagai X
    x_pos = range(len(cluster_data))

    # Buat plot
    plt.figure(figsize=(12, 5))
    plt.bar(x_pos, bb_values, color='cornflowerblue')

    # Pasang label TB sebagai xticks
    plt.xticks(x_pos, tb_values.astype(str), rotation=45, ha='right')
    plt.title(f'Peserta di Klaster {cluster_label + 1}')
    plt.xlabel('Tinggi Badan (TB)')
    plt.ylabel('Berat Badan (BB)')
    plt.tight_layout()
    plt.show()

# %%
for cluster_id in range(k_manual):
    print(f"\nCluster {cluster_id + 1}:")
    print(senior_pr_clustered[senior_pr_clustered['cluster'] == cluster_id])
# Out:
# Cluster 1:
#                           CLUB                            NAMA  TAHUN L/P  \
# 56                   MAVERICKS            DITA ULI LUMBAN GAOL   2006   P
# 100           POLTEKBANG MEDAN          EMIYA ANGELITA TARIGAN   2005   P
# 280          UKM TAEKWONDO USU       ANATASYA RONATAMA SITORUS   2005   P
# 446              Taekwondo UMA             Lira Perna Manurung   2004   P
# 421  68.0            SENIOR        2
# 475  74.0            SENIOR        2
# 481  72.5            SENIOR        2
# 492  67.0            SENIOR        2

# %% [markdown]
# # SEMUA TABEL

# %%
def save_cluster_results(dataframe, filename):
    dataframe.to_csv(filename, index=False)
    print(f"\nHasil klastering telah disimpan ke: {filename}")

# Prakadet A Lk
print("\nTabel Klaster Prakadet A Laki-laki:")
print(prakadet_a_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_a_lk_clustered, '/content/prakadet_a_lk_clusters.csv')

# Prakadet A Pr
print("\nTabel Klaster Prakadet A Perempuan:")
print(prakadet_a_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_a_pr_clustered, '/content/prakadet_a_pr_clusters.csv')

# Prakadet B LK
print("\nTabel Klaster Prakadet B Laki-laki:")
print(prakadet_b_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_b_lk_clustered, '/content/prakadet_b_lk_clusters.csv')

# Prakadet B Pr
print("\nTabel Klaster Prakadet B Perempuan:")
print(prakadet_b_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_b_pr_clustered, '/content/prakadet_b_pr_clusters.csv')

# Prakadet C Lk
print("\nTabel Klaster Prakadet C Laki-laki:")
print(prakadet_c_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_c_lk_clustered, '/content/prakadet_c_lk_clusters.csv')

# Prakadet C Pr
print("\nTabel Klaster Prakadet C Perempuan:")
print(prakadet_c_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(prakadet_c_pr_clustered, '/content/prakadet_c_pr_clusters.csv')

# Kadet Lk
print("\nTabel Klaster Kadet Laki-laki:")
print(kadet_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(kadet_lk_clustered, '/content/kadet_lk_clusters.csv')

# Kadet Pr
print("\nTabel Klaster Kadet Perempuan:")
print(kadet_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(kadet_pr_clustered, '/content/kadet_pr_clusters.csv')

# Junior Lk
print("\nTabel Klaster Junior Laki-laki:")
print(junior_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(junior_lk_clustered, '/content/junior_lk_clusters.csv')

# Junior Pr
print("\nTabel Klaster Junior Perempuan:")
print(junior_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(junior_pr_clustered, '/content/junior_pr_clusters.csv')

# Senior Lk
print("\nTabel Klaster Senior Laki-laki:")
print(senior_lk_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(senior_lk_clustered, '/content/senior_lk_clusters.csv')

# Senior Pr
print("\nTabel Klaster Senior Perempuan:")
print(senior_pr_clustered[['NAMA', 'TB', 'BB', 'cluster']])
save_cluster_results(senior_pr_clustered, '/content/senior_pr_clusters.csv')
# Out:
# Tabel Klaster Prakadet A Laki-laki:
# 343    Aulia Salsabila Br Perangin-angin  126.0  28.00        0
# 378                    RASYIQAH AZ-ZAHRA  122.0  20.00        2
# 379                  MAHIRA HASNA KAMILA  132.0  24.00        0
# 409                 Ashira Islami Yadika  145.0  35.00        1
# 427                JASMINE AZZAHRA PUTRI  118.0  18.00        2
# 458               KEYSHA KAIRINA RITONGA  125.0  25.00        0
#
# Hasil klastering telah disimpan ke: /content/prakadet_b_pr_clusters.csv
#
# Tabel Klaster Prakadet C Laki-laki:
#                              NAMA     TB    BB  cluster
# 4                  RIFQI SYAHBANA  140.0  30.0        2
# 5         BAREN HOT PAKKAR LINGGA  136.0  33.0        2
# 6        AZKA ABQARY AZMI SIAHAAN  145.0  39.0        0
# 7          ALARIC TRISTAN TARIGAN  152.0  42.0        0
# 8        LIONEL HABIBINTA MELIALA  143.0  45.0        0
# ..                            ...    ...   ...      ...
# 534             Jerick Aldiansyah  130.0  29.2        1
# 537                 Kevin Tananda  135.0  37.0        2
# 544             ENRIQUE LIONGSPIN  145.0  38.0        0
# 545  ALDO AMSAL WILLIAM ARITONANG  145.0  43.0        0
# 546        ALDWIN NAUNGI TAMBUNAN  143.0  53.0        0
#
# [76 rows x 4 columns]
#
# Hasil klastering telah disimpan ke: /content/prakadet_c_lk_clusters.csv
#
# Tabel Klaster Prakadet C Perempuan:
#                               NAMA     TB    BB  cluster
# 3                    AISYAH AQILLA  149.0  49.0        1
# 22        CHELSEA MEISIA BR MARBUN  140.0  30.0        2
# 39                YOHANA TOGATOROP  140.0  48.0        1
# 40        NASRO FRANSISKA SIHOTANG  143.0  45.0        1
# 42               MELATI QUEN MALAU  130.0  24.0        0
# 43           FELICIA INEZ SIMAMORA  141.0  30.0        2
# 44             KHALISA YUMMA CAPAH  139.0  30.0        2
# 46             ELIF CESYA SIHOTANG  135.0  28.0        0
# 73   Arkana Sachi Al-Faqih Harahap  138.0  29.0        2
# 94    ANNABELLA  KYLIE LIAURENCIUS  140.0  40.0        2
# 126   MEILITKA MEHULIKA BR GINTING  130.0  30.0        0
# 138       Aqila Farahnisa Pasaribu  155.0  49.0        1
# 172      Hanna Shahirah Hutahayan   140.0  30.0        2
# 200        YUMNA SHIDQIYYAH RAHMAN  133.0  24.0        0
# 337                 WIDYA SYAKIRAH  152.0  56.0        1
# 344     Ain Aulia Br Perangi-angin  144.0  33.0        2
# 363            CATARINA SITANGGANG  146.0  44.0        1
# 385             AIRY BUNGA CANTIKA  134.0  26.0        0
# 386         MARSYA ZAFIRAH FATHIHA  140.0  33.0        2
# 387                  NAZLAH AMELIA  144.0  33.0        2
# 388                 IZZAH INSYIRAH  128.0  28.0        0
# 389           FAKHIRA AMIRATUSYIFA  150.0  37.0        1
# 413         Medina Syahira Habibah  124.0  25.0        0
# 415                Naomi Dea Barus  140.0  35.0        2
# 424             Alya Najwa Kamilah  140.0  40.0        2
# 429               MUZDHALIFA ZAHRA  140.0  26.0        2
# 432          ALINKA YUAN SYAHPUTRI  136.0  26.0        0
#
# Hasil klastering telah disimpan ke: /content/prakadet_c_pr_clusters.csv
#
# Tabel Klaster Kadet Laki-laki:
#                                      NAMA     TB    BB  cluster
# 13                     EVAN SATRIA BANGUN  151.0  49.0        0
# 17                  FECHDRI AGINA SIREGAR  150.0  37.0        1
# 18                 CHRISKI ANANTA SIREGAR  152.0  37.0        1
# 24                Sinar Husni Adi Siregar  170.0  61.0        2
# 51                    TRISTAN SIMORANGKIR  160.0  53.0        0
# ..                                    ...    ...   ...      ...
# 538                        Nicholas Kosim  140.0  42.0        1
# 539                  Devon Lowell Ghozali  145.0  47.0        1
# 540  Yohanes Christian Junior Simanjuntak  150.0  51.0        0
# 547                         RODO PASARIBU  133.0  35.0        3
# 549                   PASCAL HOSEA SILAEN  143.0  38.0        1
#
# [88 rows x 4 columns]
#
# Hasil klastering telah disimpan ke: /content/kadet_lk_clusters.csv
#
# Tabel Klaster Kadet Perempuan:
#                              NAMA     TB    BB  cluster
# 9              AURELA KARINA BABA  150.0  44.0        2
# 10          DEARTY TABITHA TOBING  158.0  51.0        0
# 11          FERLITA NURAINI AUZIA  151.0  51.0        0
# 12   STEVANY PEBINA BR. SEMBIRING  154.0  59.0        0
# 14         IRIYEL SURAMANA SITEPU  160.0  47.0        0
# ..                            ...    ...   ...      ...
# 464     AXELIA GASHANI DARA PUTRI  144.0  37.0        1
# 465  ZHIVANA KAWURI PUTRI TUNGGAL  145.0  35.0        1
# 551        Wanti Octaviany Haloho  155.0  42.0        2
# 552               Aulia Hutabarat  150.0  53.0        0
# 553                  Alwyna Purba  159.0  58.0        3
#
# [66 rows x 4 columns]
#
# Hasil klastering telah disimpan ke: /content/kadet_pr_clusters.csv
#
# Tabel Klaster Junior Laki-laki:
#                             NAMA     TB    BB  cluster
# 27      M. FAKHRI YUDHISTIRANDRA  150.0  45.0        1
# 28   Arnold septiawan ompusunggu  164.0  51.0        0
# 29       Tiras Wijaya Sembiring   165.0  48.0        0
# 30           Hagai lumban tobing  165.0  51.0        0
# 31       William supratno berutu  167.0  59.0        0
# ..                           ...    ...   ...      ...
# 523       Jeafer Alexander Thiam  166.0  56.0        0
# 541           Joy Yakin Pasaribu  165.0  59.0        0
# 542                 Aditya Rafqy  168.0  63.0        0
# 548               ORVIN PASARIBU  158.0  43.0        1
# 550           Baginda ButarButar  169.0  50.0        0
#
# [75 rows x 4 columns]
#
# Hasil klastering telah disimpan ke: /content/junior_lk_clusters.csv
#
# Tabel Klaster Junior Perempuan:
#                               NAMA     TB    BB  cluster
# 16                 HARUMI SAHPUTRI  155.0  46.0        0
# 26           Lawren Ivana Pasaribu  160.0  63.0        2
# 32   Lastri Roma Arta siringoringo  155.0  52.0        0
# 33                Riesya Salsabila  158.0  59.0        2
# 59             MAULIDZA AYU ANDITA  160.0  52.0        0
# 86            NABILA HAFNI SARAGIH  150.0  42.0        1
# 97                     NAZWA FAHRI  169.0  58.0        2
# 103                   YUS SYAHRANI  158.0  45.0        0
# 104                KEYLA ALIF KHAN  162.0  52.0        0
